# %%
import pandas as pd
import numpy as np

# %%
banks = pd.read_excel(r"C:\Users\prana\Downloads\All banks - consolidated.xlsx")

# %%
banks.head()
# Out:
#                                        Unnamed: 0    Unnamed: 1  \
# 0  Quarterly Results of Federal Bank (in Rs. Cr.)          Bank
# 1                                         Dec '19  Federal Bank
# 2                                         Sep '19  Federal Bank
# 3                                         Jun '19  Federal Bank
# 4                                         Mar '19  Federal Bank
#
#                 Interest Earned                Unnamed: 3  \
# 0  (a) Int. /Disc. on Adv/Bills  (b) Income on Investment
# 1                      2,702.78                    536.11
# 2                      2,637.66                    527.44
# 3                      2,606.08                    555.23
# 4                      2,413.05                    536.38
#
#                       Unnamed: 4 Unnamed: 5    Unnamed: 6        EXPENDITURE  \
# 0  (c) Int. on balances With RBI     others  Other Income  Interest Expended
# ...
