# %%
import pandas as pd
import numpy as np

# %%
banks = pd.read_excel(r"C:\Users\prana\Downloads\All banks - consolidated.xlsx")

# %%
banks.head()
# Out:
#   Quarterly Results of Federal Bank (in Rs. Cr.)          Bank  \
# 0                                        Dec '19  Federal Bank
# 1                                        Sep '19  Federal Bank
# 2                                        Jun '19  Federal Bank
# 3                                        Mar '19  Federal Bank
# 4                                        Dec '18  Federal Bank
#
#   (a) Int. /Disc. on Adv/Bills (b) Income on Investment  \
# 0                      2702.78                   536.11
# 1                      2637.66                   527.44
# 2                      2606.08                   555.23
# 3                      2413.05                   536.38
# 4                      2386.62                   505.58
#
#    (c) Int. on balances With RBI others Other Income  \
# 0                          35.27   56.2       407.86
# 1                          38.11  51.04       420.92
# 2                          19.72  48.27       391.52
# ...

# %%
banks['Operating Expenses'] = banks['Employees Cost'] + banks['Other Expenses']

# %%
banks['Net Profit Margin'] = banks['Net Profit/(Loss) For the Period']

# %%
banks['ROI'] = banks['(b) Income on Investment']

# %%
banks['ROA'] = banks['Return on Assets %']

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 48 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Quarterly Results of Federal Bank (in Rs. Cr.)                           480 non-null    object
#  1   Bank                                                                     480 non-null    object
#  2   (a) Int. /Disc. on Adv/Bills                                             480 non-null    object
#  3   (b) Income on Investment                                                 480 non-null    object
#  4   (c) Int. on balances With RBI                                            480 non-null    float64
#  5   others                                                                   480 non-null    object
# ...

# %%
banks['(c) Int. on balances With RBI'] = banks['(c) Int. on balances With RBI'].astype(str)

banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 47 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Quarterly Results of Federal Bank (in Rs. Cr.)                           480 non-null    object
#  1   Bank                                                                     480 non-null    object
#  2   (a) Int. /Disc. on Adv/Bills                                             480 non-null    object
#  3   (b) Income on Investment                                                 480 non-null    object
#  4   (c) Int. on balances With RBI                                            480 non-null    object
#  5   others                                                                   480 non-null    object
# ...

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 48 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Quarterly Results of Federal Bank (in Rs. Cr.)                           480 non-null    object
#  1   Bank                                                                     480 non-null    object
#  2   (a) Int. /Disc. on Adv/Bills                                             480 non-null    object
#  3   (b) Income on Investment                                                 480 non-null    object
#  4   (c) Int. on balances With RBI                                            480 non-null    float64
#  5   others                                                                   480 non-null    object
# ...

# %%
new_banks2 =  banks[['Operating Expenses','Net Profit Margin','ROI','ROA','Earning before Interest and Tax','Equity Share Capital']]

# %%
new_banks2.head()
# Out:
#   Operating Expenses Net Profit Margin     ROI   ROA  \
# 0       414.76404.21            440.64  536.11  0.26
# 1       440.70385.20            416.70  527.44  0.26
# 2       397.84365.09            384.21  555.23  0.24
# 3       370.15383.35            381.51  536.38  0.25
# 4       353.66361.35            333.63  505.58  0.23
#
#    Earning before Interest and Tax Equity Share Capital
# 0                          3738.22               398.46
# 1                          3675.17               397.62
# 2                          3620.82               397.20
# 3                          3444.04               397.01
# 4                          3299.96               396.78

# %%
new_banks2.shape
# Out:
# (480, 6)

# %%
stockprices = pd.read_excel(r"C:\Users\prana\Downloads\stockprices.xlsx")

# %%
stockprices.head()
# Out:
#   Quaterly Time          Bank  Closing Share price  Basic eps   PE Ratio
# 0       Dec '19  Federal Bank                85.33       2.21  38.610860
# 1       Sep '19  Federal Bank                88.11       2.10  41.957143
# 2       Jun '19  Federal Bank               104.27       1.94  53.747423
# 3       Mar '19  Federal Bank                90.08       1.92  46.916667
# 4       Dec '18  Federal Bank                89.70       1.68  53.392857

# %%
new_banks2['PE Ratio'] = stockprices['PE Ratio']
# Out:
# C:\Users\prana\AppData\Local\Temp/ipykernel_16852/3258682180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_banks2['PE Ratio'] = stockprices['PE Ratio']

# %%
new_banks2.head()
# Out:
#   Operating Expenses Net Profit Margin     ROI   ROA  \
# 0       414.76404.21            440.64  536.11  0.26
# 1       440.70385.20            416.70  527.44  0.26
# 2       397.84365.09            384.21  555.23  0.24
# 3       370.15383.35            381.51  536.38  0.25
# 4       353.66361.35            333.63  505.58  0.23
#
#    Earning before Interest and Tax Equity Share Capital  Closing Share price  \
# 0                          3738.22               398.46                85.33
# 1                          3675.17               397.62                88.11
# 2                          3620.82               397.20               104.27
# 3                          3444.04               397.01                90.08
# 4                          3299.96               396.78                89.70
#
#     PE Ratio
# 0  38.610860
# 1  41.957143
# 2  53.747423
# 3  46.916667
# 4  53.392857

# %%
new_banks2['Quaterly Time'] = stockprices['Quaterly Time']
new_banks2['Bank'] = stockprices['Bank']
# Out:
# C:\Users\prana\AppData\Local\Temp/ipykernel_16852/3011355938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_banks2['Quaterly Time'] = stockprices['Quaterly Time']
# C:\Users\prana\AppData\Local\Temp/ipykernel_16852/3011355938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_banks2['Bank'] = stockprices['Bank']

# %%
new_banks2.head()
# Out:
#   Operating Expenses Net Profit Margin     ROI   ROA  \
# 0       414.76404.21            440.64  536.11  0.26
# 1       440.70385.20            416.70  527.44  0.26
# 2       397.84365.09            384.21  555.23  0.24
# 3       370.15383.35            381.51  536.38  0.25
# 4       353.66361.35            333.63  505.58  0.23
#
#    Earning before Interest and Tax Equity Share Capital  Closing Share price  \
# 0                          3738.22               398.46                85.33
# 1                          3675.17               397.62                88.11
# 2                          3620.82               397.20               104.27
# 3                          3444.04               397.01                90.08
# 4                          3299.96               396.78                89.70
#
#     PE Ratio Quaterly Time          Bank
# 0  38.610860       Dec '19  Federal Bank
# 1  41.957143       Sep '19  Federal Bank
# 2  53.747423       Jun '19  Federal Bank
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(new_banks2.corr())
# Out:
# <AxesSubplot:>

# %%
new_banks2.to_csv('new_banks2.csv')

# %%
train_data = pd.read_excel(r"C:\Users\prana\Downloads\banks2_train.xlsx")

# %%
test_data = pd.read_csv(r"C:\Users\prana\Downloads\new_banks2_test.csv")

# %%
train_data.head()
# Out:
#    Net Profit Margin     ROI   ROA  Earning before Interest and Tax  \
# 0             333.63  505.58  0.23                          3299.96
# 1             266.04  488.34  0.19                          3087.81
# 2             262.71  507.15  0.20                          2938.24
# 3             144.99  516.95  0.11                          2862.14
# 4             260.01  482.20  0.22                          2729.83
#
#    Equity Share Capital  Closing Share price    PE Ratio  Year  Month  \
# 0                396.78                89.70   53.392857    18      4
# 1                396.12                68.01   50.753731    18      3
# 2                395.52                77.83   58.518797    18      2
# 3                394.43                84.82  114.621622    18      1
# 4                393.27               103.17   77.571429    17      4
#
#            Bank
# 0  Federal Bank
# 1  Federal Bank
# 2  Federal Bank
# 3  Federal Bank
# 4  Federal Bank

# %%
test_data.head()
# Out:
#   Net Profit Margin     ROI   ROA  Earning before Interest and Tax  \
# 0            440.64  536.11  0.26                          3738.22
# 1             416.7  527.44  0.26                          3675.17
# 2            384.21  555.23  0.24                          3620.82
# 3            381.51  536.38  0.25                          3444.04
# 4              96.7     154  1.03                           990.89
#
#   Equity Share Capital  Closing Share price   PE Ratio  Year  Month  \
# 0               398.46                85.33  38.610860    19      4
# 1               397.62                88.11  41.957143    19      3
# 2                397.2               104.27  53.747423    19      2
# 3               397.01                90.08  46.916667    19      1
# 4               310.21               166.78  53.455128    19      4
#
#            Bank
# 0  Federal Bank
# 1  Federal Bank
# 2  Federal Bank
# 3  Federal Bank
# 4      DCB Bank

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Net Profit Margin                400 non-null    object
#  1   ROI                              400 non-null    float64
#  2   ROA                              400 non-null    float64
#  3   Earning before Interest and Tax  400 non-null    float64
#  4   Equity Share Capital             400 non-null    float64
#  5   Closing Share price              400 non-null    float64
#  6   PE Ratio                         400 non-null    float64
#  7   Year                             400 non-null    int64
#  8   Month                            400 non-null    int64
#  9   Bank                             400 non-null    object
# dtypes: float64(6), int64(2), object(2)
# memory usage: 31.4+ KB

# %%
test_data['Net Profit Margin']=test_data['Net Profit Margin'].str.replace(',','')
train_data['Net Profit Margin']=train_data['Net Profit Margin'].astype(str)
train_data['Net Profit Margin']=train_data['Net Profit Margin'].str.replace(',','')

# %%
train_data['ROI']=train_data['ROI'].astype(str)
train_data['ROA']=train_data['ROA'].astype(str)
train_data['Earning before Interest and Tax']=train_data['Earning before Interest and Tax'].astype(str)
train_data['Equity Share Capital']=train_data['Equity Share Capital'].astype(str)
train_data['Closing Share price']=train_data['Closing Share price'].astype(str)
train_data['PE Ratio']=train_data['PE Ratio'].astype(str)

# %%
train_data['ROI']=train_data['ROI'].str.replace(',','')
train_data['ROA']=train_data['ROA'].str.replace(',','')
train_data['Earning before Interest and Tax']=train_data['Earning before Interest and Tax'].str.replace(',','')
train_data['Equity Share Capital']=train_data['Equity Share Capital'].str.replace(',','')
train_data['Closing Share price']=train_data['Closing Share price'].str.replace(',','')
train_data['PE Ratio']=train_data['PE Ratio'].str.replace(',','')

# %%
X_train = train_data.drop(['Closing Share price'], axis = 1)
y_train = train_data['Closing Share price']

# %%
X_test = test_data.drop(['Closing Share price'], axis = 1)
y_test = test_data['Closing Share price']

# %%
X_test.shape
# Out:
# (80, 9)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe_encoder = OneHotEncoder(handle_unknown='ignore')

# %%
train_data['Bank'].value_counts()
# Out:
# Federal Bank             20
# DCB Bank                 20
# YES Bank                 20
# Indian Bank              20
# SBI                      20
# HDFC                     20
# UCO Bank                 20
# Central Bank of India    20
# Canara Bank              20
# Bank of India            20
# Bank of Baroda           20
# PNB                      20
# Karnataka Bank           20
# IDBI                     20
# Axis Bank                20
# Union bank of India      20
# Syndicate Bank           20
# IndusInd Bank            20
# ICICI Bank               20
# Kotak Mahindra Bank      20
# Name: Bank, dtype: int64

# %%
train_data_bank = ohe_encoder.fit_transform(train_data[['Bank']])
test_data_bank = ohe_encoder.transform(test_data[['Bank']])
ohe_encoder.categories_
# Out:
# [array(['Axis Bank', 'Bank of Baroda', 'Bank of India', 'Canara Bank',
#         'Central Bank of India', 'DCB Bank', 'Federal Bank', 'HDFC',
#         'ICICI Bank', 'IDBI', 'Indian Bank', 'IndusInd Bank',
#         'Karnataka Bank', 'Kotak Mahindra Bank', 'PNB', 'SBI',
#         'Syndicate Bank', 'UCO Bank', 'Union bank of India', 'YES Bank'],
#        dtype=object)]

# %%
train_data_bank.shape
# Out:
# (400, 20)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
import seaborn as sns
preprocessor = ColumnTransformer(
    transformers=[        
        ('cat', ohe_encoder, ['Bank'])],
remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression
lreg_v1 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('regressor', LinearRegression())])
lreg_v1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Bank'])])),
#                 ('regressor', LinearRegression())])

# %%
final_feature_names = lreg_v1['preprocessor'].get_feature_names()

# %%
final_feature_names
# Out:
# ['cat__x0_Axis Bank',
#  'cat__x0_Bank of Baroda',
#  'cat__x0_Bank of India',
#  'cat__x0_Canara Bank',
#  'cat__x0_Central Bank of India',
#  'cat__x0_DCB Bank',
#  'cat__x0_Federal Bank',
#  'cat__x0_HDFC',
#  'cat__x0_ICICI Bank',
#  'cat__x0_IDBI',
#  'cat__x0_Indian Bank',
#  'cat__x0_IndusInd Bank',
#  'cat__x0_Karnataka Bank',
#  'cat__x0_Kotak Mahindra Bank',
#  'cat__x0_PNB',
#  'cat__x0_SBI',
#  'cat__x0_Syndicate Bank',
#  'cat__x0_UCO Bank',
#  'cat__x0_Union bank of India',
#  'cat__x0_YES Bank',
#  'Net Profit Margin',
#  'ROI',
#  'ROA',
#  'Earning before Interest and Tax',
#  'Equity Share Capital',
#  'PE Ratio',
#  'Year',
#  'Month']

# %%
y_pred = lreg_v1.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16852/3456367976.py in <module>
# ----> 1 y_pred = lreg_v1.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     417         for _, name, transform in self._iter(with_final=False):
#     418             Xt = transform.transform(Xt)
# --> 419         return self.steps[-1][-1].predict(Xt, **predict_params)
#     420
# ...

# %%
type(test_data['Net Profit Margin'][0])
# Out:
# str

# %%
test_data.head()
# Out:
#   Net Profit Margin     ROI   ROA  Earning before Interest and Tax  \
# 0            440.64  536.11  0.26                          3738.22
# 1             416.7  527.44  0.26                          3675.17
# 2            384.21  555.23  0.24                          3620.82
# 3            381.51  536.38  0.25                          3444.04
# 4              96.7     154  1.03                           990.89
#
#   Equity Share Capital  Closing Share price   PE Ratio  Year  Month  \
# 0               398.46                85.33  38.610860    19      4
# 1               397.62                88.11  41.957143    19      3
# 2                397.2               104.27  53.747423    19      2
# 3               397.01                90.08  46.916667    19      1
# 4               310.21               166.78  53.455128    19      4
#
#            Bank
# 0  Federal Bank
# 1  Federal Bank
# 2  Federal Bank
# 3  Federal Bank
# 4      DCB Bank
